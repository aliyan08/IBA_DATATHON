# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle
from sklearn.impute import KNNImputer

# %%
#read data
data = pd.read_csv('./Data/train_data.csv')

# %%
data.head()
# Out:
#   Investor_ID   Age  Annual_Income  Investment_Amount  Risk_Tolerance_Score  \
# 0  0003HW9UAA  51.0            NaN            87300.0                   358
# 1  000ELHLBPV  37.0        81658.0           152598.0                   792
# 2  000G6CHJON   NaN            NaN            77767.0                   359
# 3  000K09D0JB  54.0        42344.0            13261.0                   366
# 4  000NTH4YTU  63.0        48898.0           193990.0                   792
#
#    Months_of_Investing_Experience  Number_of_Active_Investments  \
# 0                              13                           3.0
# 1                              23                           4.0
# 2                              57                           4.0
# 3                             115                           1.0
# 4                              53                           4.0
#
#    Potential_Return_Rate  Investment_Duration  Investment_to_Income_Ratio  \
# ...

# %%
#check for missing values
data.isnull().sum()
# Out:
# Investor_ID                           0
# Age                               32840
# Annual_Income                     22626
# Investment_Amount                 18033
# Risk_Tolerance_Score                  0
# Months_of_Investing_Experience        0
# Number_of_Active_Investments       4512
# Potential_Return_Rate             11244
# Investment_Duration                   0
# Investment_to_Income_Ratio            0
# Education                             0
# Employment_Status                     0
# Marital_Status                    42906
# Owns_Property                         0
# Has_Dependents                        0
# Investment_Sector                     0
# Has_Investment_Advisor             3849
# Investment_Failed                     0
# dtype: int64

# %%
#change rows according to ascending order of Age
data = data.sort_values(by='Age')

# %%
data.head()
# Out:
#        Investor_ID   Age  Annual_Income  Investment_Amount  \
# 159557  PJCXW642UT  18.0        50258.0           196480.0
# 80464   CVGUUO8US9  18.0        31339.0           158693.0
# 46437   7FVSO1DRN8  18.0       139073.0           225987.0
# 46456   7FYRXX1JD9  18.0        16251.0            27362.0
# 46474   7G3IS62S9I  18.0        30428.0                NaN
#
#         Risk_Tolerance_Score  Months_of_Investing_Experience  \
# 159557                   331                              78
# 80464                    761                               6
# 46437                    723                              33
# 46456                    422                              38
# 46474                    785                              32
#
#         Number_of_Active_Investments  Potential_Return_Rate  \
# 159557                           4.0                   5.91
# 80464                            4.0                  11.50
# ...

# %%
#drop investor ID column
data = data.drop('Investor_ID', axis=1)

# %%
data.head()
# Out:
#          Age  Annual_Income  Investment_Amount  Risk_Tolerance_Score  \
# 159557  18.0        50258.0           196480.0                   331
# 80464   18.0        31339.0           158693.0                   761
# 46437   18.0       139073.0           225987.0                   723
# 46456   18.0        16251.0            27362.0                   422
# 46474   18.0        30428.0                NaN                   785
#
#         Months_of_Investing_Experience  Number_of_Active_Investments  \
# 159557                              78                           4.0
# 80464                                6                           4.0
# 46437                               33                           3.0
# 46456                               38                           1.0
# 46474                               32                           1.0
#
#         Potential_Return_Rate  Investment_Duration  \
# 159557                   5.91                   12
# ...

# %%
#Convert has invested column to 0 and 1
data['Has_Investment_Advisor'] = data['Has_Investment_Advisor'].map({False:0, True:1})

# %%
#unique values in marital status
data['Marital_Status'].unique()
# Out:
# array(['Divorced', 'Single', 'Div', 'Sgl', nan, 'Married', 'Marr'],
#       dtype=object)

# %%
#label encode marital_status column
data['Marital_Status'] = data['Marital_Status'].map({'Married':0, 'Single':1, 'Divorced':2, 'Widowed':3})

# %%
#columns with missing values
missing_cols = data.columns[data.isnull().any()]
missing_cols
# Out:
# Index(['Age', 'Annual_Income', 'Investment_Amount',
#        'Number_of_Active_Investments', 'Potential_Return_Rate',
#        'Marital_Status', 'Has_Investment_Advisor'],
#       dtype='object')

# %%
imputer = KNNImputer(n_neighbors=3)

# %%
#using imputer to fill
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1632\533052437.py in ?()
#       1 #using imputer to fill missing values
# ----> 2 data[missing_cols] = imputer.fit_transform(data[missing_cols])
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_set_output.py in ?(self, X, *args, **kwargs)
#     293     @wraps(f)
#     294     def wrapped(self, X, *args, **kwargs):
# --> 295         data_to_wrap = f(self, X, *args, **kwargs)
#     296         if isinstance(data_to_wrap, tuple):
#     297             # only wrap the first output for cross decomposition
#     298             return_tuple = (
#
# ...
