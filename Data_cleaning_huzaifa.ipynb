# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_pickle('data_cleaned.pkl')

# %%
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

# Setting up the iterative imputer
imputer = IterativeImputer(max_iter=10, random_state=0)

# Columns to impute
columns_to_impute = ['Age', 'Annual_Income', 'Investment_Amount', 'Number_of_Active_Investments', 'Potential_Return_Rate', 'Marital_Status', 'Has_Investment_Advisor']

# Performing the imputation
imputed_data = imputer.fit_transform(df[columns_to_impute])

# Filling the original dataframe with the imputed data
df[columns_to_impute] = imputed_data

print('Iterative imputation completed.')
# Out:
# Iterative imputation completed.

# %%
df.head()
# Out:
#          Age  Annual_Income  Investment_Amount  Risk_Tolerance_Score  \
# 0  51.000000   82664.208539            87300.0                   358
# 1  37.000000   81658.000000           152598.0                   792
# 2  45.984723   82633.045587            77767.0                   359
# 3  54.000000   42344.000000            13261.0                   366
# 4  63.000000   48898.000000           193990.0                   792
#
#    Months_of_Investing_Experience  Number_of_Active_Investments  \
# 0                              13                           3.0
# 1                              23                           4.0
# 2                              57                           4.0
# 3                             115                           1.0
# 4                              53                           4.0
#
#    Potential_Return_Rate  Investment_Duration  Investment_to_Income_Ratio  \
# 0              18.100000                   12                        0.85
# 1              14.060000                   24                        0.86
# 2               4.310000                   60                        0.60
# 3              13.474238                   60                        0.21
# 4               5.650000                   48                        0.82
#
#     Education Employment_Status  Marital_Status Owns_Property Has_Dependents  \
# 0  Bachelor's         Part-time        0.996711            No             No
# 1         PhD     Self-employed        0.999955           Yes             No
# 2    Master's        Unemployed        1.000000            No             No
# 3         PhD         Part-time        0.000000            No             No
# 4    Master's     Self-employed        1.000000           Yes             No
#
#   Investment_Sector  Has_Investment_Advisor  Investment_Failed
# 0             Other                     1.0                  0
# 1              Auto                     0.0                  1
# 2         Education                     1.0                  0
# 3         Education                     1.0                  0
# 4          Business                     1.0                  0

# %%
df.to_pickle('data_imputed.pkl')
